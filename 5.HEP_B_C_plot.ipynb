# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_excel('/content/drive/My Drive/Colab Notebooks/hepatitisdataset.xlsx')

# %%
df.head()
# Out:
#   Institute                 Date  Age_Yr  ...  HBsAg  Anti_HCV  Syndrome
# 0    ShSMCH  2018-10-12 00:00:00      35  ...    1.0         1          N
# 1    ShSMCH  2018-10-12 00:00:00      32  ...    1.0         1          N
# 2    ShSMCH  2018-10-12 00:00:00      36  ...    1.0         1          N
# 3    ShSMCH  2018-10-12 00:00:00      50  ...    1.0         1          N
# 4    ShSMCH  2018-10-12 00:00:00      31  ...    1.0         1          N
#
# [5 rows x 22 columns]

# %%
df['Sex'].value_counts()
# Out:
# 1    561
# 0    435
# 4      1
# Name: Sex, dtype: int64

# %%
labels=['Male','Female','others']
sizes=[435,561,1]
colors=['gold', 'yellowgreen', 'lightcoral']
explode = (0.0, 0, 0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.show()

# %%
df['Age_Yr'].describe()
# Out:
# count    997.000000
# mean      33.651956
# std       10.099119
# min       12.000000
# 25%       25.000000
# 50%       32.000000
# 75%       40.000000
# max       70.000000
# Name: Age_Yr, dtype: float64

# %%
df['Age_Yr']>11
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 992    True
# 993    True
# 994    True
# 995    True
# 996    True
# Name: Age_Yr, Length: 997, dtype: bool

# %%
df[df['Age_Yr']<71]
# Out:
#     Institute                 Date  Age_Yr  ...  HBsAg  Anti_HCV  Syndrome
# 0      ShSMCH  2018-10-12 00:00:00      35  ...    1.0         1          N
# 1      ShSMCH  2018-10-12 00:00:00      32  ...    1.0         1          N
# 2      ShSMCH  2018-10-12 00:00:00      36  ...    1.0         1          N
# 3      ShSMCH  2018-10-12 00:00:00      50  ...    1.0         1          N
# 4      ShSMCH  2018-10-12 00:00:00      31  ...    1.0         1          N
# ..        ...                  ...     ...  ...    ...       ...        ...
# 992    ShSMCH           13/12/2018      29  ...    1.0         1          N
# 993    ShSMCH           13/12/2018      50  ...    1.0         1          N
# 994    ShSMCH           13/12/2018      18  ...    1.0         1          N
# 995    ShSMCH           13/12/2018      21  ...    1.0         1          N
# 996    ShSMCH           13/12/2018      35  ...    1.0         1          N
#
# [997 rows x 22 columns]

# %%
labels=['11-20','21-30','31-40','41-50','51-60','61-70']
sizes=[68,373,338,151,64,3]
colors=['gold', 'yellowgreen', 'lightcoral','lightskyblue','yellow','red']
explode = (0, 0, 0,0,0,0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('Age distribution')
plt.show()

# %%
y=df['Syndrome ']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l=LabelEncoder()

# %%
y=l.fit_transform(y)

# %%
y
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
# ...

# %%
y_data=pd.DataFrame(y,columns=['SYndrome'])

# %%
y_data['SYndrome'].value_counts()
# Out:
# 2    992
# 0      3
# 1      2
# Name: SYndrome, dtype: int64

# %%
labels=['NO','HEP_B+C','HEP_B']
sizes=[992,3,2]
colors=['gold', 'yellowgreen', 'lightcoral']
explode = (0, 0, 0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('Syndrome')
plt.show()

# %%
labels = [r'NO (99.5 %)', r'HEP_B+C (0.3 %)', 
r'HEP_B (0.2 %)']
sizes =[992,3,2]
colors = ['yellowgreen', 'gold', 'lightskyblue']
patches, texts = plt.pie(sizes, colors=colors, startangle=90)
plt.legend(patches, labels, loc="best")
# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')
plt.tight_layout()
plt.title('Syndrome')
plt.show()

# %%
df['Surgery'].value_counts()
# Out:
# 1.0    820
# 0.0    174
# Name: Surgery, dtype: int64

# %%
labels=['Yes','No']
sizes=[174,820]
colors=['gold', 'yellowgreen']
explode = (0, 0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('SUrgery')
plt.show()

# %%
df['Blood_trans'].value_counts()
# Out:
# 1.0    911
# 0.0     84
# 4.0      1
# Name: Blood_trans, dtype: int64

# %%
labels=['No','Yes','Others']
sizes=[911,84,1]
colors=['gold', 'yellowgreen','lightskyblue']
explode = (0, 0,0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('Blood Transfer')
plt.show()

# %%
df['Alcohol'].value_counts()
# Out:
# 1.0    978
# 0.0     17
# Name: Alcohol, dtype: int64

# %%
labels=['Yes','No']
sizes=[17,978]
colors=['gold', 'yellowgreen']
explode = (0, 0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('Alcohol')
plt.show()

# %%
df["Sex_Exp"].value_counts()
# Out:
# 1    987
# 0     10
# Name: Sex_Exp, dtype: int64

# %%
labels=['Yes','No']
sizes=[10,987]
colors=['gold', 'red']
explode = (0, 0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('SEx')
plt.show()

# %%
df.columns
# Out:
# Index(['Institute', 'Date', 'Age_Yr', 'Sex', 'Religion', 'Past_Hep_B',
#        'b_Past_Hep_C', 'a_Family_Hep_B', 'b_Family_Hep_C', 'Dialysis', 'CLD',
#        'Diabetes', 'Blood_trans', 'Surgery', 'Alcohol', 'Sex_Exp', 'IV_Drug',
#        'Vaccination', 'Vac_Schedule', 'HBsAg', 'Anti_HCV', 'Syndrome '],
#       dtype='object')

# %%
df['IV_Drug'].value_counts()
# Out:
# 1.0    985
# 0.0     11
# Name: IV_Drug, dtype: int64

# %%
labels=['Yes','No']
sizes=[11,985]
colors=['green', 'white']
explode = (0, 0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('Drug')
plt.show()

# %%
df['Vaccination'].value_counts()
# Out:
# 1.0    900
# 0.0     96
# Name: Vaccination, dtype: int64

# %%
labels=['Yes','No']
sizes=[96,900]
colors=['blue', 'red']
explode = (0, 0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('vaccination')
plt.show()

# %%
df['HBsAg'].value_counts()
# Out:
# 1.0    992
# 0.0      4
# Name: HBsAg, dtype: int64

# %%
labels=['Positive','Negative']
sizes=[4,992]
colors=['yellow', 'pink']
explode = (0, 0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('HBsAG')
plt.show()

# %%
df['Anti_HCV'].value_counts()
# Out:
# 1    995
# 0      2
# Name: Anti_HCV, dtype: int64

# %%
labels=['Positive','Negative']
sizes=[2,995]
colors=['yellow', 'pink']
explode = (0, 0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('vaccination')
plt.show()

# %%
labels = [r'positive (.2 %)', r'Negative (99.8 %)']
sizes =[2,995]
colors = ['yellowgreen', 'gold', ]
patches, texts = plt.pie(sizes, colors=colors, startangle=90)
plt.legend(patches, labels, loc="best")
# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')
plt.tight_layout()
plt.title('ANTI HCV')
plt.show()

# %%
df.columns
# Out:
# Index(['Institute', 'Date', 'Age_Yr', 'Sex', 'Religion', 'Past_Hep_B',
#        'b_Past_Hep_C', 'a_Family_Hep_B', 'b_Family_Hep_C', 'Dialysis', 'CLD',
#        'Diabetes', 'Blood_trans', 'Surgery', 'Alcohol', 'Sex_Exp', 'IV_Drug',
#        'Vaccination', 'Vac_Schedule', 'HBsAg', 'Anti_HCV', 'Syndrome '],
#       dtype='object')

# %%
df['a_Family_Hep_B'].value_counts()
# Out:
# 1    981
# 0     16
# Name: a_Family_Hep_B, dtype: int64

# %%
df['b_Family_Hep_C'].value_counts()
# Out:
# 1.0    965
# 0.0     31
# Name: b_Family_Hep_C, dtype: int64

# %%
labels=['Yes','No']
sizes=[16,981]
colors=['yellow', 'pink']
explode = (0, 0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('a_Family_Hep_B')
plt.show()

# %%
labels=['Yes','No']
sizes=[31,965]
colors=['red', 'orange']
explode = (0, 0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('b_Family_Hep_C')
plt.show()

# %%
level=['Syndrome','Surgery','Blood-transf','Alcohol','Sexual-exp','Drug-abuse','Hap-B-vaccination','HBV-vaccine schedule','Anti HCB','Family-Hap-B','Family-Hap-C']

# %%
sizes=[[.5,17.5,8.5,1.7,1,1.1,9.6,.4,0.2,1.6,3.1]]

# %%
df1=pd.DataFrame(level,columns=['level'])

# %%
#df2=pd.DataFrame(sizes,columns=['sizes'])

# %%
df3=pd.DataFrame(sizes,columns=['Syndrome','Surgery','Blood-transf','Alcohol','Sexual-exp','Drug-abuse','Hap-B-vaccination','HBV-vaccine schedule','Anti HCB','Family-Hap-B','Family-Hap-C'])

# %%
df3
# Out:
#    Syndrome  Surgery  Blood-transf  ...  Anti HCB  Family-Hap-B  Family-Hap-C
# 0       0.5     17.5           8.5  ...       0.2           1.6           3.1
#
# [1 rows x 11 columns]

# %%
data={'Level':['Syndrome','Surgery','Blood-transf','Alcohol','Sexual-exp','Drug-abuse','Hap-B-vaccination','HBV-vaccine schedule','Anti HCB','Family-Hap-B','Family-Hap-C'],
      'sizes':[.5,17.5,8.5,1.7,1,1.1,9.6,.4,0.2,1.6,3.1]   
}

# %%
ndf=pd.DataFrame(data)

# %%
ndf.head()
# Out:
#           Level  sizes
# 0      Syndrome    0.5
# 1       Surgery   17.5
# 2  Blood-transf    8.5
# 3       Alcohol    1.7
# 4    Sexual-exp    1.0

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import numpy as np
 
Level=['Syndrome','Surgery','Blood-transf','Alcohol','Sexual-exp','Drug-abuse','Hap-B-vaccination','HBV-vaccine schedule',
      'Anti HCB','Family-Hap-B','Family-Hap-C']
pos = np.arange(len(Level))
Happiness_Index=[.5,17.5,8.5,1.7,1,1.1,9.6,.4,0.2,1.6,3.1]
plt.figure(figsize=(16,8)) 
plt.bar(pos,Happiness_Index,color='blue',edgecolor='black')
plt.xticks(pos, Level)
plt.xlabel('Features', fontsize=16)
plt.ylabel('Value of Parcent', fontsize=16)
plt.title('Barchart - Prevelent symtomps',fontsize=20)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
sns.set_style('white')
 
Level=['Syndrome','Surgery','Blood-transf','Alcohol','Sexual-exp','Drug-abuse','Hap-B-vaccination','HBV-vaccine schedule',
      'Anti HCB','Family-Hap-B','Family-Hap-C']
pos = np.arange(len(Level))
Happiness_Index=[.5,17.5,8.5,1.7,1,1.1,9.6,.4,0.2,1.6,3.1]


plt.figure(figsize=(10,8)) 
plt.barh(pos,Happiness_Index,color='blue',edgecolor='black')
plt.yticks(pos, Level)
plt.xlabel(' Parcent of feature values', fontsize=16)
plt.ylabel('Features', fontsize=16)
plt.title('Barchart - Prevelent symtomp',fontsize=20)
plt.show()

# %%
labels=[r'Syndrome(.5%)',r'Surgery(17.5%)',r'Blood-transf(8.5%)',r'Alcohol(1.7%)',r'Sexual-exp(1.0%)',r'Drug-abuse(1.1%)',r'Hap-B-vaccination(9.6%)','HBV-vaccine schedule(.4%)',
      'Anti HCB(.2%)',r'Family-Hap-B(1.6)',r'Family-Hap-C(3.1%)']
sizes=[.5,17.5,8.5,1.7,1,1.1,9.6,.4,0.2,1.6,3.1]
colors = ['yellowgreen', 'gold','red','blue','green','silver','black','white','pink','red','orange' ]
plt.figure(figsize=(10,6))
patches, texts = plt.pie(sizes, colors=colors, startangle=90)
plt.legend(patches, labels, loc="best")
# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')
plt.tight_layout()
plt.title('Prevalent Symptoms')
plt.show()
